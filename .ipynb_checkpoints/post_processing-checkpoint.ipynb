# %%
import os
import json
import glob2
import numpy as np
import matplotlib.pyplot as plt

# %%
experiment_folders_list = glob2.glob("experiments/*")
experiment_folders_list
# Out:
# ['experiments/04M_09D-13H_30M_51S']

# %%
experiment_dir = experiment_folders_list[0]
experiment_dir
# Out:
# 'experiments/04M_09D-13H_30M_51S'

# %%
experiments_list = np.sort(glob2.glob("{}/*".format(experiment_dir)))
experiments_list
# Out:
# array(['experiments/04M_09D-13H_30M_51S/experiment_0',
#        'experiments/04M_09D-13H_30M_51S/experiment_1',
#        'experiments/04M_09D-13H_30M_51S/experiment_2',
#        'experiments/04M_09D-13H_30M_51S/experiment_3',
#        'experiments/04M_09D-13H_30M_51S/experiment_4',
#        'experiments/04M_09D-13H_30M_51S/experiment_5',
#        'experiments/04M_09D-13H_30M_51S/experiment_6',
#        'experiments/04M_09D-13H_30M_51S/experiment_7'], dtype='|S44')

# %%
for experiment_path in experiments_list:
    config_path = os.path.join(experiment_path, "config.json") 
    with open(config_path, "r") as config_infile:
        config_info = json.load(config_infile)
    
    data_path = os.path.join(experiment_path, "data", "distance_to_queen_history.json")
    with open(data_path, "r") as data_infile:
        data = json.load(data_infile)["distance_from_queen"]
    
    averages = []
    for data_i in data:
        average_distance = data_i["average"]
        averages.append(average_distance)
        plt.plot(averages)
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-b3f454c3abb4> in <module>()
#      13         averages.append(average_distance)
#      14         plt.plot(averages)
# ---> 15         plt.show()
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/ipykernel/pylab/backend_inline.pyc in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/IPython/core/display.pyc in display(*objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/IPython/core/formatters.pyc in format(self, obj, include, exclude)
#     171             md = None
#     172             try:
# --> 173                 data = formatter(obj)
#     174             except:
#     175                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/IPython/core/formatters.pyc in catch_format_error(method, self, *args, **kwargs)
#     215     """show traceback on failed format call"""
#     216     try:
# --> 217         r = method(self, *args, **kwargs)
#     218     except NotImplementedError:
#     219         # don't warn on NotImplementedErrors
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     238
#     239     if 'png' in formats:
# --> 240         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     241     if 'retina' in formats or 'png2x' in formats:
#     242         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     122
#     123     bytes_io = BytesIO()
# --> 124     fig.canvas.print_figure(bytes_io, **kw)
#     125     data = bytes_io.getvalue()
#     126     if fmt == 'svg':
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2198                     orientation=orientation,
#    2199                     dryrun=True,
# -> 2200                     **kwargs)
#    2201                 renderer = self.figure._cachedRenderer
#    2202                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     543
#     544     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 545         FigureCanvasAgg.draw(self)
#     546         renderer = self.get_renderer()
#     547         original_dpi = renderer.dpi
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in draw(self)
#     462
#     463         try:
# --> 464             self.figure.draw(self.renderer)
#     465         finally:
#     466             RendererAgg.lock.release()
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/matplotlib/figure.pyc in draw(self, renderer)
#    1142
#    1143             mimage._draw_list_compositing_images(
# -> 1144                 renderer, self, dsu, self.suppressComposite)
#    1145
#    1146             renderer.close_group('figure')
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in draw(self, renderer, inframe)
#    2424             renderer.stop_rasterizing()
#    2425
# -> 2426         mimage._draw_list_compositing_images(renderer, self, dsu)
#    2427
#    2428         renderer.close_group('axes')
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in draw(self, renderer, *args, **kwargs)
#    1134         renderer.open_group(__name__)
#    1135
# -> 1136         ticks_to_draw = self._update_ticks(renderer)
#    1137         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1138                                                                 renderer)
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in _update_ticks(self, renderer)
#     967
#     968         interval = self.get_view_interval()
# --> 969         tick_tups = [t for t in self.iter_ticks()]
#     970         if self._smart_bounds:
#     971             # handle inverted limits
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in iter_ticks(self)
#     911         """
#     912         majorLocs = self.major.locator()
# --> 913         majorTicks = self.get_major_ticks(len(majorLocs))
#     914         self.major.formatter.set_locs(majorLocs)
#     915         majorLabels = [self.major.formatter(val, i)
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in get_major_ticks(self, numticks)
#    1322             # update the new tick label properties from the old
#    1323             for i in range(numticks - len(self.majorTicks)):
# -> 1324                 tick = self._get_tick(major=True)
#    1325                 self.majorTicks.append(tick)
#    1326
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick(self, major)
#    1727         else:
#    1728             tick_kw = self._minor_tick_kw
# -> 1729         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1730
#    1731     def _get_label(self):
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     154         self.label1 = self._get_text1()
#     155         self.label = self.label1  # legacy name
# --> 156         self.label2 = self._get_text2()
#     157
#     158         self.gridOn = gridOn
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_text2(self)
#     403         t = mtext.Text(
#     404             x=0, y=1,
# --> 405             fontproperties=font_manager.FontProperties(size=self._labelsize),
#     406             color=self._labelcolor,
#     407             verticalalignment=vert,
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.pyc in __init__(self, family, style, variant, weight, stretch, size, fname, _init)
#     684         self._family = _normalize_font_family(rcParams['font.family'])
#     685         self._slant = rcParams['font.style']
# --> 686         self._variant = rcParams['font.variant']
#     687         self._weight = rcParams['font.weight']
#     688         self._stretch = rcParams['font.stretch']
#
# /Users/mliuzzolino/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in __getitem__(self, key)
#     934     def __getitem__(self, key):
#     935         inverse_alt = None
# --> 936         if key in _deprecated_map:
#     937             alt_key, alt_val, inverse_alt = _deprecated_map[key]
#     938             warnings.warn(self.msg_depr % (key, alt_key))
#
# KeyboardInterrupt:

# %%
data
# Out:
# [{u'average': 1.0787385107349945,
#   u'distances': [1.4849242404917498,
#    0.6800735254367722,
#    1.4849242404917498,
#    0.6800735254367722,
#    1.1236102527122116,
#    1.1853269591129698,
#    1.1853269591129698,
